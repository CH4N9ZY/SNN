# %%
import numpy as np
import torch
import os

# %%
def read2Dspikes(filename):
    '''
    Reads two dimensional binary spike file and returns a TD event.
    It is the same format used in neuromorphic datasets NMNIST & NCALTECH101.
    
    The binary file is encoded as follows:
        * Each spike event is represented by a 40 bit number.
        * First 8 bits (bits 39-32) represent the xID of the neuron.
        * Next 8 bits (bits 31-24) represent the yID of the neuron.
        * Bit 23 represents the sign of spike event: 0=>OFF event, 1=>ON event.
        * The last 23 bits (bits 22-0) represent the spike event timestamp in microseconds.
    Arguments:
        * ``filename`` (``string``): path to the binary file.
    '''
    with open(filename, 'rb') as inputFile:
        inputByteArray = inputFile.read()
    inputAsInt = np.asarray([x for x in inputByteArray])
    xEvent =   inputAsInt[0::5]
    yEvent =   inputAsInt[1::5]
    pEvent =   inputAsInt[2::5] >> 7
    tEvent =( (inputAsInt[2::5] << 16) | (inputAsInt[3::5] << 8) | (inputAsInt[4::5]) ) & 0x7FFFFF
    return event(xEvent, yEvent, pEvent, tEvent/1000) # convert spike times to ms

# %%
class event():
    '''
    This class provides a way to store, read, write and visualize spike event.
    Members:
        * ``x`` (numpy ``int`` array): `x` index of spike event.
        * ``y`` (numpy ``int`` array): `y` index of spike event
                                        (not used if the spatial dimension is 1).
        * ``p`` (numpy ``int`` array): `polarity` or `channel` index of spike event.
        * ``t`` (numpy ``double`` array): `timestamp` of spike event.
                                        Time is assumend to be in ms.
    '''
    def __init__(self, xEvent, yEvent, pEvent, tEvent):
        if yEvent is None:
            self.dim = 1
        else:
            self.dim = 2
        
        self.x = xEvent if type(xEvent) is np.ndarray else np.asarray(xEvent)
        # x spatial dimension
        self.y = yEvent if type(yEvent) is np.ndarray else np.asarray(yEvent)
        # y spatial dimension
        self.p = pEvent if type(pEvent) is np.ndarray else np.asarray(pEvent)
        # spike polarity
        self.t = tEvent if type(tEvent) is np.ndarray else np.asarray(tEvent)
        # time stamp in ms
        
        if not issubclass(self.x.dtype.type, np.integer):
            self.x = self.x.astype('int')
        if not issubclass(self.p.dtype.type, np.integer):
            self.p = self.p.astype('int')
        if self.dim == 2:
            if not issubclass(self.y.dtype.type, np.integer):
                self.y = self.y.astype('int')
        
        self.p -= self.p.min()
    
    def toSpikeTensor(self, emptyTensor, samplingTime=1, randomShift=False, binningMode='OR'):
        # Sampling time in ms
        '''
        Returns a numpy tensor that contains the spike events sampled in bins of `samplingTime`.
        The tensor is of dimension (channels, height, width, time) or``CHWT``.
        Arguments:
            * ``emptyTensor`` (``numpy or torch tensor``): an empty tensor to hold spike data 
            * ``samplingTime``: the width of time bin to use.
            * ``randomShift``: flag to shift the sample in time or not. Default: False.
            * ``binningMode``: the way spikes are binned. 'SUM' or 'OR' are supported. Default: 'OR'
        '''
        if randomShift is True:
            tSt = np.random.randint(
                max(
                    int(self.t.min() / samplingTime),
                    int(self.t.max() / samplingTime) - emptyTensor.shape[3],
                    emptyTensor.shape[3] - int(self.t.max() / samplingTime),
                    1,
                )
            )
        else:
            tSt = 0
        
        xEvent = np.round(self.x).astype(int)
        pEvent = np.round(self.p).astype(int)
        tEvent = np.round(self.t/samplingTime).astype(int) - tSt
        
        if self.dim == 1:
            validInd = np.argwhere( (xEvent < emptyTensor.shape[2]) &
                                    (pEvent < emptyTensor.shape[0]) &
                                    (tEvent < emptyTensor.shape[3]) &
                                    (xEvent >= 0) &
                                    (pEvent >= 0) &
                                    (tEvent >= 0))
            if binningMode.upper() == 'OR':
                emptyTensor[pEvent[validInd],
                            0, 
                            xEvent[validInd],
                            tEvent[validInd]] = 1/samplingTime
            elif binningMode.upper() == 'SUM':
                emptyTensor[pEvent[validInd],
                            0, 
                            xEvent[validInd],
                            tEvent[validInd]] += 1/samplingTime
            else:
                raise Exception('Unsupported binningMode. It was {}'.format(binningMode))

        elif self.dim == 2:
            yEvent = np.round(self.y).astype(int)
            validInd = np.argwhere((xEvent < emptyTensor.shape[2]) &
                                   (yEvent < emptyTensor.shape[1]) & 
                                   (pEvent < emptyTensor.shape[0]) &
                                   (tEvent < emptyTensor.shape[3]) &
                                   (xEvent >= 0) &
                                   (yEvent >= 0) & 
                                   (pEvent >= 0) &
                                   (tEvent >= 0))

            if binningMode.upper() == 'OR':
                emptyTensor[pEvent[validInd], 
                            yEvent[validInd],
                            xEvent[validInd],
                            tEvent[validInd]] = 1/samplingTime
            elif binningMode.upper() == 'SUM':
                emptyTensor[pEvent[validInd], 
                            yEvent[validInd],
                            xEvent[validInd],
                            tEvent[validInd]] += 1/samplingTime
            else:
                raise Exception('Unsupported binningMode. It was {}'.format(binningMode))
            
        return emptyTensor

# %%
def convert_to_npy(mode, out_dir):
    dataPath = '../../../DATA/N-MNIST/raw/NMNISTsmall/'
    if mode == 'train':
        samples = np.loadtxt(dataPath + 'train1K.txt').astype('int')
    elif mode == 'test':
        samples = np.loadtxt(dataPath + 'test100.txt').astype('int')
    else:
        print('typo!')
    for sample in samples:
        file_dir = sample[0]
        label  = sample[1]
        data = read2Dspikes(dataPath + str(file_dir) + '.bs2').toSpikeTensor(torch.zeros((2,34,34,300)),samplingTime=1.0)
        torch.save(data, out_dir + mode + '/' + str(file_dir) + '_' + str(label) + '.pt')
        print('The ' + str(file_dir) + ', label: ' + str(label) + ' successfully saved')

# %%
out_dir = '../../../DATA/N-MNIST/processed/NMNISTsmall/'

# %%
convert_to_npy('train', out_dir)
# Out:
# The 1, label: 5 successfully saved
# The 2, label: 0 successfully saved
# The 3, label: 4 successfully saved
# The 4, label: 1 successfully saved
# The 5, label: 9 successfully saved
# The 6, label: 2 successfully saved
# The 7, label: 1 successfully saved
# The 8, label: 3 successfully saved
# The 9, label: 1 successfully saved
# The 10, label: 4 successfully saved
# The 11, label: 3 successfully saved
# The 12, label: 5 successfully saved
# The 13, label: 3 successfully saved
# The 14, label: 6 successfully saved
# The 15, label: 1 successfully saved
# The 16, label: 7 successfully saved
# The 17, label: 2 successfully saved
# The 18, label: 8 successfully saved
# The 19, label: 6 successfully saved
# The 20, label: 9 successfully saved
# The 21, label: 4 successfully saved
# The 22, label: 0 successfully saved
# The 23, label: 9 successfully saved
# The 24, label: 1 successfully saved
# The 25, label: 1 successfully saved
# The 26, label: 2 successfully saved
# The 27, label: 4 successfully saved
# The 28, label: 3 successfully saved
# The 29, label: 2 successfully saved
# The 30, label: 7 successfully saved
# The 31, label: 3 successfully saved
# The 32, label: 8 successfully saved
# The 33, label: 6 successfully saved
# The 34, label: 9 successfully saved
# The 35, label: 0 successfully saved
# The 36, label: 5 successfully saved
# The 37, label: 6 successfully saved
# The 38, label: 0 successfully saved
# The 39, label: 7 successfully saved
# The 40, label: 6 successfully saved
# The 41, label: 1 successfully saved
# The 42, label: 8 successfully saved
# The 43, label: 7 successfully saved
# The 44, label: 9 successfully saved
# The 45, label: 3 successfully saved
# The 46, label: 9 successfully saved
# The 47, label: 8 successfully saved
# The 48, label: 5 successfully saved
# The 49, label: 9 successfully saved
# The 50, label: 3 successfully saved
# The 51, label: 3 successfully saved
# The 52, label: 0 successfully saved
# The 53, label: 7 successfully saved
# The 54, label: 4 successfully saved
# The 55, label: 9 successfully saved
# The 56, label: 8 successfully saved
# The 57, label: 0 successfully saved
# The 58, label: 9 successfully saved
# The 59, label: 4 successfully saved
# The 60, label: 1 successfully saved
# The 61, label: 4 successfully saved
# The 62, label: 4 successfully saved
# The 63, label: 6 successfully saved
# The 64, label: 0 successfully saved
# The 65, label: 4 successfully saved
# The 66, label: 5 successfully saved
# The 67, label: 6 successfully saved
# The 68, label: 1 successfully saved
# The 69, label: 0 successfully saved
# The 70, label: 0 successfully saved
# The 71, label: 1 successfully saved
# The 72, label: 7 successfully saved
# The 73, label: 1 successfully saved
# The 74, label: 6 successfully saved
# The 75, label: 3 successfully saved
# The 76, label: 0 successfully saved
# The 77, label: 2 successfully saved
# The 78, label: 1 successfully saved
# The 79, label: 1 successfully saved
# The 80, label: 7 successfully saved
# The 81, label: 9 successfully saved
# The 82, label: 0 successfully saved
# The 83, label: 2 successfully saved
# The 84, label: 6 successfully saved
# The 85, label: 7 successfully saved
# The 86, label: 8 successfully saved
# The 87, label: 3 successfully saved
# The 88, label: 9 successfully saved
# The 89, label: 0 successfully saved
# The 90, label: 4 successfully saved
# The 91, label: 6 successfully saved
# The 92, label: 7 successfully saved
# The 93, label: 4 successfully saved
# The 94, label: 6 successfully saved
# The 95, label: 8 successfully saved
# The 96, label: 0 successfully saved
# The 97, label: 7 successfully saved
# The 98, label: 8 successfully saved
# The 99, label: 3 successfully saved
# The 100, label: 1 successfully saved
# The 101, label: 5 successfully saved
# The 102, label: 7 successfully saved
# The 103, label: 1 successfully saved
# The 104, label: 7 successfully saved
# The 105, label: 1 successfully saved
# The 106, label: 1 successfully saved
# The 107, label: 6 successfully saved
# The 108, label: 3 successfully saved
# The 109, label: 0 successfully saved
# The 110, label: 2 successfully saved
# The 111, label: 9 successfully saved
# The 112, label: 3 successfully saved
# The 113, label: 1 successfully saved
# The 114, label: 1 successfully saved
# The 115, label: 0 successfully saved
# The 116, label: 4 successfully saved
# The 117, label: 9 successfully saved
# The 118, label: 2 successfully saved
# The 119, label: 0 successfully saved
# The 120, label: 0 successfully saved
# The 121, label: 2 successfully saved
# The 122, label: 0 successfully saved
# The 123, label: 2 successfully saved
# The 124, label: 7 successfully saved
# The 125, label: 1 successfully saved
# The 126, label: 8 successfully saved
# The 127, label: 6 successfully saved
# The 128, label: 4 successfully saved
# The 129, label: 1 successfully saved
# The 130, label: 6 successfully saved
# The 131, label: 3 successfully saved
# The 132, label: 4 successfully saved
# The 133, label: 5 successfully saved
# The 134, label: 9 successfully saved
# The 135, label: 1 successfully saved
# The 136, label: 3 successfully saved
# The 137, label: 3 successfully saved
# The 138, label: 8 successfully saved
# The 139, label: 5 successfully saved
# The 140, label: 4 successfully saved
# The 141, label: 7 successfully saved
# The 142, label: 7 successfully saved
# The 143, label: 4 successfully saved
# The 144, label: 2 successfully saved
# The 145, label: 8 successfully saved
# The 146, label: 5 successfully saved
# The 147, label: 8 successfully saved
# The 148, label: 6 successfully saved
# The 149, label: 7 successfully saved
# The 150, label: 3 successfully saved
# The 151, label: 4 successfully saved
# The 152, label: 6 successfully saved
# The 153, label: 1 successfully saved
# The 154, label: 9 successfully saved
# The 155, label: 9 successfully saved
# The 156, label: 6 successfully saved
# The 157, label: 0 successfully saved
# The 158, label: 3 successfully saved
# The 159, label: 7 successfully saved
# The 160, label: 2 successfully saved
# The 161, label: 8 successfully saved
# The 162, label: 2 successfully saved
# The 163, label: 9 successfully saved
# The 164, label: 4 successfully saved
# The 165, label: 4 successfully saved
# The 166, label: 6 successfully saved
# The 167, label: 4 successfully saved
# The 168, label: 9 successfully saved
# The 169, label: 7 successfully saved
# The 170, label: 0 successfully saved
# The 171, label: 9 successfully saved
# The 172, label: 2 successfully saved
# The 173, label: 9 successfully saved
# The 174, label: 5 successfully saved
# The 175, label: 1 successfully saved
# The 176, label: 5 successfully saved
# The 177, label: 9 successfully saved
# The 178, label: 1 successfully saved
# The 179, label: 2 successfully saved
# The 180, label: 3 successfully saved
# The 181, label: 2 successfully saved
# The 182, label: 3 successfully saved
# The 183, label: 5 successfully saved
# The 184, label: 9 successfully saved
# The 185, label: 1 successfully saved
# The 186, label: 7 successfully saved
# The 187, label: 6 successfully saved
# The 188, label: 2 successfully saved
# The 189, label: 8 successfully saved
# The 190, label: 2 successfully saved
# The 191, label: 2 successfully saved
# The 192, label: 5 successfully saved
# The 193, label: 0 successfully saved
# The 194, label: 7 successfully saved
# The 195, label: 4 successfully saved
# The 196, label: 9 successfully saved
# The 197, label: 7 successfully saved
# The 198, label: 8 successfully saved
# The 199, label: 3 successfully saved
# The 200, label: 2 successfully saved
# The 201, label: 1 successfully saved
# The 202, label: 1 successfully saved
# The 203, label: 8 successfully saved
# The 204, label: 3 successfully saved
# The 205, label: 6 successfully saved
# The 206, label: 1 successfully saved
# The 207, label: 0 successfully saved
# The 208, label: 3 successfully saved
# The 209, label: 1 successfully saved
# The 210, label: 0 successfully saved
# The 211, label: 0 successfully saved
# The 212, label: 1 successfully saved
# The 213, label: 7 successfully saved
# The 214, label: 2 successfully saved
# The 215, label: 7 successfully saved
# The 216, label: 3 successfully saved
# The 217, label: 0 successfully saved
# The 218, label: 4 successfully saved
# The 219, label: 6 successfully saved
# The 220, label: 5 successfully saved
# The 221, label: 2 successfully saved
# The 222, label: 6 successfully saved
# The 223, label: 4 successfully saved
# The 224, label: 7 successfully saved
# The 225, label: 1 successfully saved
# The 226, label: 8 successfully saved
# The 227, label: 9 successfully saved
# The 228, label: 9 successfully saved
# The 229, label: 3 successfully saved
# The 230, label: 0 successfully saved
# The 231, label: 7 successfully saved
# The 232, label: 1 successfully saved
# The 233, label: 0 successfully saved
# The 234, label: 2 successfully saved
# The 235, label: 0 successfully saved
# The 236, label: 3 successfully saved
# The 237, label: 5 successfully saved
# The 238, label: 4 successfully saved
# The 239, label: 6 successfully saved
# The 240, label: 5 successfully saved
# The 241, label: 8 successfully saved
# The 242, label: 6 successfully saved
# The 243, label: 3 successfully saved
# The 244, label: 7 successfully saved
# The 245, label: 5 successfully saved
# The 246, label: 8 successfully saved
# The 247, label: 0 successfully saved
# The 248, label: 9 successfully saved
# The 249, label: 1 successfully saved
# The 250, label: 0 successfully saved
# The 251, label: 3 successfully saved
# The 252, label: 1 successfully saved
# The 253, label: 2 successfully saved
# The 254, label: 2 successfully saved
# The 255, label: 3 successfully saved
# The 256, label: 3 successfully saved
# The 257, label: 6 successfully saved
# The 258, label: 4 successfully saved
# The 259, label: 7 successfully saved
# The 260, label: 5 successfully saved
# The 261, label: 0 successfully saved
# The 262, label: 6 successfully saved
# The 263, label: 2 successfully saved
# The 264, label: 7 successfully saved
# The 265, label: 9 successfully saved
# The 266, label: 8 successfully saved
# The 267, label: 5 successfully saved
# The 268, label: 9 successfully saved
# The 269, label: 2 successfully saved
# The 270, label: 1 successfully saved
# The 271, label: 1 successfully saved
# The 272, label: 4 successfully saved
# The 273, label: 4 successfully saved
# The 274, label: 5 successfully saved
# The 275, label: 6 successfully saved
# The 276, label: 4 successfully saved
# The 277, label: 1 successfully saved
# The 278, label: 2 successfully saved
# The 279, label: 5 successfully saved
# The 280, label: 3 successfully saved
# The 281, label: 9 successfully saved
# The 282, label: 3 successfully saved
# The 283, label: 9 successfully saved
# The 284, label: 0 successfully saved
# The 285, label: 5 successfully saved
# The 286, label: 9 successfully saved
# The 287, label: 6 successfully saved
# The 288, label: 5 successfully saved
# The 289, label: 7 successfully saved
# The 290, label: 4 successfully saved
# The 291, label: 1 successfully saved
# The 292, label: 3 successfully saved
# The 293, label: 4 successfully saved
# The 294, label: 0 successfully saved
# The 295, label: 4 successfully saved
# The 296, label: 8 successfully saved
# The 297, label: 0 successfully saved
# The 298, label: 4 successfully saved
# The 299, label: 3 successfully saved
# The 300, label: 6 successfully saved
# The 301, label: 8 successfully saved
# The 302, label: 7 successfully saved
# The 303, label: 6 successfully saved
# The 304, label: 0 successfully saved
# The 305, label: 9 successfully saved
# The 306, label: 7 successfully saved
# The 307, label: 5 successfully saved
# The 308, label: 7 successfully saved
# The 309, label: 2 successfully saved
# The 310, label: 1 successfully saved
# The 311, label: 1 successfully saved
# The 312, label: 6 successfully saved
# The 313, label: 8 successfully saved
# The 314, label: 9 successfully saved
# The 315, label: 4 successfully saved
# The 316, label: 1 successfully saved
# The 317, label: 5 successfully saved
# The 318, label: 2 successfully saved
# The 319, label: 2 successfully saved
# The 320, label: 9 successfully saved
# The 321, label: 0 successfully saved
# The 322, label: 3 successfully saved
# The 323, label: 9 successfully saved
# The 324, label: 6 successfully saved
# The 325, label: 7 successfully saved
# The 326, label: 2 successfully saved
# The 327, label: 0 successfully saved
# The 328, label: 3 successfully saved
# The 329, label: 5 successfully saved
# The 330, label: 4 successfully saved
# The 331, label: 3 successfully saved
# The 332, label: 6 successfully saved
# The 333, label: 5 successfully saved
# The 334, label: 8 successfully saved
# The 335, label: 9 successfully saved
# The 336, label: 5 successfully saved
# The 337, label: 4 successfully saved
# The 338, label: 7 successfully saved
# The 339, label: 4 successfully saved
# The 340, label: 2 successfully saved
# The 341, label: 7 successfully saved
# The 342, label: 3 successfully saved
# The 343, label: 4 successfully saved
# The 344, label: 8 successfully saved
# The 345, label: 9 successfully saved
# The 346, label: 1 successfully saved
# The 347, label: 9 successfully saved
# The 348, label: 2 successfully saved
# The 349, label: 8 successfully saved
# The 350, label: 7 successfully saved
# The 351, label: 9 successfully saved
# The 352, label: 1 successfully saved
# The 353, label: 8 successfully saved
# The 354, label: 7 successfully saved
# The 355, label: 4 successfully saved
# The 356, label: 1 successfully saved
# The 357, label: 3 successfully saved
# The 358, label: 1 successfully saved
# The 359, label: 1 successfully saved
# The 360, label: 0 successfully saved
# The 361, label: 2 successfully saved
# The 362, label: 3 successfully saved
# The 363, label: 9 successfully saved
# The 364, label: 4 successfully saved
# The 365, label: 9 successfully saved
# The 366, label: 2 successfully saved
# The 367, label: 1 successfully saved
# The 368, label: 6 successfully saved
# The 369, label: 8 successfully saved
# The 370, label: 4 successfully saved
# The 371, label: 7 successfully saved
# The 372, label: 7 successfully saved
# The 373, label: 4 successfully saved
# The 374, label: 4 successfully saved
# The 375, label: 9 successfully saved
# The 376, label: 2 successfully saved
# The 377, label: 5 successfully saved
# The 378, label: 7 successfully saved
# The 379, label: 2 successfully saved
# The 380, label: 4 successfully saved
# The 381, label: 4 successfully saved
# The 382, label: 2 successfully saved
# The 383, label: 1 successfully saved
# The 384, label: 9 successfully saved
# The 385, label: 7 successfully saved
# The 386, label: 2 successfully saved
# The 387, label: 8 successfully saved
# The 388, label: 7 successfully saved
# The 389, label: 6 successfully saved
# The 390, label: 9 successfully saved
# The 391, label: 2 successfully saved
# The 392, label: 2 successfully saved
# The 393, label: 3 successfully saved
# The 394, label: 8 successfully saved
# The 395, label: 1 successfully saved
# The 396, label: 6 successfully saved
# The 397, label: 5 successfully saved
# The 398, label: 1 successfully saved
# The 399, label: 1 successfully saved
# The 400, label: 0 successfully saved
# The 401, label: 2 successfully saved
# The 402, label: 6 successfully saved
# The 403, label: 4 successfully saved
# The 404, label: 5 successfully saved
# The 405, label: 8 successfully saved
# The 406, label: 3 successfully saved
# The 407, label: 1 successfully saved
# The 408, label: 5 successfully saved
# The 409, label: 1 successfully saved
# The 410, label: 9 successfully saved
# The 411, label: 2 successfully saved
# The 412, label: 7 successfully saved
# The 413, label: 4 successfully saved
# The 414, label: 4 successfully saved
# The 415, label: 4 successfully saved
# The 416, label: 8 successfully saved
# The 417, label: 1 successfully saved
# The 418, label: 5 successfully saved
# The 419, label: 8 successfully saved
# The 420, label: 9 successfully saved
# The 421, label: 5 successfully saved
# The 422, label: 6 successfully saved
# The 423, label: 7 successfully saved
# The 424, label: 9 successfully saved
# The 425, label: 9 successfully saved
# The 426, label: 3 successfully saved
# The 427, label: 7 successfully saved
# The 428, label: 0 successfully saved
# The 429, label: 9 successfully saved
# The 430, label: 0 successfully saved
# The 431, label: 6 successfully saved
# The 432, label: 6 successfully saved
# The 433, label: 2 successfully saved
# The 434, label: 3 successfully saved
# The 435, label: 9 successfully saved
# The 436, label: 0 successfully saved
# The 437, label: 7 successfully saved
# The 438, label: 5 successfully saved
# The 439, label: 4 successfully saved
# The 440, label: 8 successfully saved
# The 441, label: 0 successfully saved
# The 442, label: 9 successfully saved
# The 443, label: 4 successfully saved
# The 444, label: 1 successfully saved
# The 445, label: 2 successfully saved
# The 446, label: 8 successfully saved
# The 447, label: 7 successfully saved
# The 448, label: 1 successfully saved
# The 449, label: 2 successfully saved
# The 450, label: 6 successfully saved
# The 451, label: 1 successfully saved
# The 452, label: 0 successfully saved
# The 453, label: 3 successfully saved
# The 454, label: 0 successfully saved
# The 455, label: 1 successfully saved
# The 456, label: 1 successfully saved
# The 457, label: 8 successfully saved
# The 458, label: 2 successfully saved
# The 459, label: 0 successfully saved
# The 460, label: 3 successfully saved
# The 461, label: 9 successfully saved
# The 462, label: 4 successfully saved
# The 463, label: 0 successfully saved
# The 464, label: 5 successfully saved
# The 465, label: 0 successfully saved
# The 466, label: 6 successfully saved
# The 467, label: 1 successfully saved
# The 468, label: 7 successfully saved
# The 469, label: 7 successfully saved
# The 470, label: 8 successfully saved
# The 471, label: 1 successfully saved
# The 472, label: 9 successfully saved
# The 473, label: 2 successfully saved
# The 474, label: 0 successfully saved
# The 475, label: 5 successfully saved
# The 476, label: 1 successfully saved
# The 477, label: 2 successfully saved
# The 478, label: 2 successfully saved
# The 479, label: 7 successfully saved
# The 480, label: 3 successfully saved
# The 481, label: 5 successfully saved
# The 482, label: 4 successfully saved
# The 483, label: 9 successfully saved
# The 484, label: 7 successfully saved
# The 485, label: 1 successfully saved
# The 486, label: 8 successfully saved
# The 487, label: 3 successfully saved
# The 488, label: 9 successfully saved
# The 489, label: 6 successfully saved
# The 490, label: 0 successfully saved
# The 491, label: 3 successfully saved
# The 492, label: 1 successfully saved
# The 493, label: 1 successfully saved
# The 494, label: 2 successfully saved
# The 495, label: 6 successfully saved
# The 496, label: 3 successfully saved
# The 497, label: 5 successfully saved
# The 498, label: 7 successfully saved
# The 499, label: 6 successfully saved
# The 500, label: 8 successfully saved
# The 501, label: 3 successfully saved
# The 502, label: 9 successfully saved
# The 503, label: 5 successfully saved
# The 504, label: 8 successfully saved
# The 505, label: 5 successfully saved
# The 506, label: 7 successfully saved
# The 507, label: 6 successfully saved
# The 508, label: 1 successfully saved
# The 509, label: 1 successfully saved
# The 510, label: 3 successfully saved
# The 511, label: 1 successfully saved
# The 512, label: 7 successfully saved
# The 513, label: 5 successfully saved
# The 514, label: 5 successfully saved
# The 515, label: 5 successfully saved
# The 516, label: 2 successfully saved
# The 517, label: 5 successfully saved
# The 518, label: 8 successfully saved
# The 519, label: 7 successfully saved
# The 520, label: 0 successfully saved
# The 521, label: 9 successfully saved
# The 522, label: 7 successfully saved
# The 523, label: 7 successfully saved
# The 524, label: 5 successfully saved
# The 525, label: 0 successfully saved
# The 526, label: 9 successfully saved
# The 527, label: 0 successfully saved
# The 528, label: 0 successfully saved
# The 529, label: 8 successfully saved
# The 530, label: 9 successfully saved
# The 531, label: 2 successfully saved
# The 532, label: 4 successfully saved
# The 533, label: 8 successfully saved
# The 534, label: 1 successfully saved
# The 535, label: 6 successfully saved
# The 536, label: 1 successfully saved
# The 537, label: 6 successfully saved
# The 538, label: 5 successfully saved
# The 539, label: 1 successfully saved
# The 540, label: 8 successfully saved
# The 541, label: 3 successfully saved
# The 542, label: 4 successfully saved
# The 543, label: 0 successfully saved
# The 544, label: 5 successfully saved
# The 545, label: 5 successfully saved
# The 546, label: 8 successfully saved
# The 547, label: 3 successfully saved
# The 548, label: 6 successfully saved
# The 549, label: 2 successfully saved
# The 550, label: 3 successfully saved
# The 551, label: 9 successfully saved
# The 552, label: 2 successfully saved
# The 553, label: 1 successfully saved
# The 554, label: 1 successfully saved
# The 555, label: 5 successfully saved
# The 556, label: 2 successfully saved
# The 557, label: 1 successfully saved
# The 558, label: 3 successfully saved
# The 559, label: 2 successfully saved
# The 560, label: 8 successfully saved
# The 561, label: 7 successfully saved
# The 562, label: 3 successfully saved
# The 563, label: 7 successfully saved
# The 564, label: 2 successfully saved
# The 565, label: 4 successfully saved
# The 566, label: 6 successfully saved
# The 567, label: 9 successfully saved
# The 568, label: 7 successfully saved
# The 569, label: 2 successfully saved
# The 570, label: 4 successfully saved
# The 571, label: 2 successfully saved
# The 572, label: 8 successfully saved
# The 573, label: 1 successfully saved
# The 574, label: 1 successfully saved
# The 575, label: 3 successfully saved
# The 576, label: 8 successfully saved
# The 577, label: 4 successfully saved
# The 578, label: 0 successfully saved
# The 579, label: 6 successfully saved
# The 580, label: 5 successfully saved
# The 581, label: 9 successfully saved
# The 582, label: 3 successfully saved
# The 583, label: 0 successfully saved
# The 584, label: 9 successfully saved
# The 585, label: 2 successfully saved
# The 586, label: 4 successfully saved
# The 587, label: 7 successfully saved
# The 588, label: 1 successfully saved
# The 589, label: 2 successfully saved
# The 590, label: 9 successfully saved
# The 591, label: 4 successfully saved
# The 592, label: 2 successfully saved
# The 593, label: 6 successfully saved
# The 594, label: 1 successfully saved
# The 595, label: 8 successfully saved
# The 596, label: 9 successfully saved
# The 597, label: 0 successfully saved
# The 598, label: 6 successfully saved
# The 599, label: 6 successfully saved
# The 600, label: 7 successfully saved
# The 601, label: 9 successfully saved
# The 602, label: 9 successfully saved
# The 603, label: 8 successfully saved
# The 604, label: 0 successfully saved
# The 605, label: 1 successfully saved
# The 606, label: 4 successfully saved
# The 607, label: 4 successfully saved
# The 608, label: 6 successfully saved
# The 609, label: 7 successfully saved
# The 610, label: 1 successfully saved
# The 611, label: 5 successfully saved
# The 612, label: 7 successfully saved
# The 613, label: 0 successfully saved
# The 614, label: 3 successfully saved
# The 615, label: 5 successfully saved
# The 616, label: 8 successfully saved
# The 617, label: 4 successfully saved
# The 618, label: 7 successfully saved
# The 619, label: 1 successfully saved
# The 620, label: 2 successfully saved
# The 621, label: 5 successfully saved
# The 622, label: 9 successfully saved
# The 623, label: 5 successfully saved
# The 624, label: 6 successfully saved
# The 625, label: 7 successfully saved
# The 626, label: 5 successfully saved
# The 627, label: 9 successfully saved
# The 628, label: 8 successfully saved
# The 629, label: 8 successfully saved
# The 630, label: 3 successfully saved
# The 631, label: 6 successfully saved
# The 632, label: 9 successfully saved
# The 633, label: 7 successfully saved
# The 634, label: 0 successfully saved
# The 635, label: 7 successfully saved
# The 636, label: 5 successfully saved
# The 637, label: 7 successfully saved
# The 638, label: 1 successfully saved
# The 639, label: 1 successfully saved
# The 640, label: 0 successfully saved
# The 641, label: 7 successfully saved
# The 642, label: 9 successfully saved
# The 643, label: 2 successfully saved
# The 644, label: 3 successfully saved
# The 645, label: 7 successfully saved
# The 646, label: 3 successfully saved
# The 647, label: 2 successfully saved
# The 648, label: 4 successfully saved
# The 649, label: 1 successfully saved
# The 650, label: 6 successfully saved
# The 651, label: 2 successfully saved
# The 652, label: 7 successfully saved
# The 653, label: 5 successfully saved
# The 654, label: 5 successfully saved
# The 655, label: 7 successfully saved
# The 656, label: 4 successfully saved
# The 657, label: 0 successfully saved
# The 658, label: 2 successfully saved
# The 659, label: 6 successfully saved
# The 660, label: 3 successfully saved
# The 661, label: 6 successfully saved
# The 662, label: 4 successfully saved
# The 663, label: 0 successfully saved
# The 664, label: 4 successfully saved
# The 665, label: 2 successfully saved
# The 666, label: 6 successfully saved
# The 667, label: 0 successfully saved
# The 668, label: 0 successfully saved
# The 669, label: 0 successfully saved
# The 670, label: 0 successfully saved
# The 671, label: 3 successfully saved
# The 672, label: 1 successfully saved
# The 673, label: 6 successfully saved
# The 674, label: 2 successfully saved
# The 675, label: 2 successfully saved
# The 676, label: 3 successfully saved
# The 677, label: 1 successfully saved
# The 678, label: 4 successfully saved
# The 679, label: 1 successfully saved
# The 680, label: 5 successfully saved
# The 681, label: 4 successfully saved
# The 682, label: 6 successfully saved
# The 683, label: 4 successfully saved
# The 684, label: 7 successfully saved
# The 685, label: 2 successfully saved
# The 686, label: 8 successfully saved
# The 687, label: 7 successfully saved
# The 688, label: 9 successfully saved
# The 689, label: 2 successfully saved
# The 690, label: 0 successfully saved
# The 691, label: 5 successfully saved
# The 692, label: 1 successfully saved
# The 693, label: 4 successfully saved
# The 694, label: 2 successfully saved
# The 695, label: 8 successfully saved
# The 696, label: 3 successfully saved
# The 697, label: 2 successfully saved
# The 698, label: 4 successfully saved
# The 699, label: 1 successfully saved
# The 700, label: 5 successfully saved
# The 701, label: 4 successfully saved
# The 702, label: 6 successfully saved
# The 703, label: 0 successfully saved
# The 704, label: 7 successfully saved
# The 705, label: 9 successfully saved
# The 706, label: 8 successfully saved
# The 707, label: 4 successfully saved
# The 708, label: 9 successfully saved
# The 709, label: 8 successfully saved
# The 710, label: 0 successfully saved
# The 711, label: 1 successfully saved
# The 712, label: 1 successfully saved
# The 713, label: 0 successfully saved
# The 714, label: 2 successfully saved
# The 715, label: 2 successfully saved
# The 716, label: 3 successfully saved
# The 717, label: 2 successfully saved
# The 718, label: 4 successfully saved
# The 719, label: 4 successfully saved
# The 720, label: 5 successfully saved
# The 721, label: 8 successfully saved
# The 722, label: 6 successfully saved
# The 723, label: 5 successfully saved
# The 724, label: 7 successfully saved
# The 725, label: 7 successfully saved
# The 726, label: 8 successfully saved
# The 727, label: 8 successfully saved
# The 728, label: 9 successfully saved
# The 729, label: 7 successfully saved
# The 730, label: 4 successfully saved
# The 731, label: 7 successfully saved
# The 732, label: 3 successfully saved
# The 733, label: 2 successfully saved
# The 734, label: 0 successfully saved
# The 735, label: 8 successfully saved
# The 736, label: 6 successfully saved
# The 737, label: 8 successfully saved
# The 738, label: 6 successfully saved
# The 739, label: 1 successfully saved
# The 740, label: 6 successfully saved
# The 741, label: 8 successfully saved
# The 742, label: 9 successfully saved
# The 743, label: 4 successfully saved
# The 744, label: 0 successfully saved
# The 745, label: 9 successfully saved
# The 746, label: 0 successfully saved
# The 747, label: 4 successfully saved
# The 748, label: 1 successfully saved
# The 749, label: 5 successfully saved
# The 750, label: 4 successfully saved
# The 751, label: 7 successfully saved
# The 752, label: 5 successfully saved
# The 753, label: 3 successfully saved
# The 754, label: 7 successfully saved
# The 755, label: 4 successfully saved
# The 756, label: 9 successfully saved
# The 757, label: 8 successfully saved
# The 758, label: 5 successfully saved
# The 759, label: 8 successfully saved
# The 760, label: 6 successfully saved
# The 761, label: 3 successfully saved
# The 762, label: 8 successfully saved
# The 763, label: 6 successfully saved
# The 764, label: 9 successfully saved
# The 765, label: 9 successfully saved
# The 766, label: 1 successfully saved
# The 767, label: 8 successfully saved
# The 768, label: 3 successfully saved
# The 769, label: 5 successfully saved
# The 770, label: 8 successfully saved
# The 771, label: 6 successfully saved
# The 772, label: 5 successfully saved
# The 773, label: 9 successfully saved
# The 774, label: 7 successfully saved
# The 775, label: 2 successfully saved
# The 776, label: 5 successfully saved
# The 777, label: 0 successfully saved
# The 778, label: 8 successfully saved
# The 779, label: 5 successfully saved
# The 780, label: 1 successfully saved
# The 781, label: 1 successfully saved
# The 782, label: 0 successfully saved
# The 783, label: 9 successfully saved
# The 784, label: 1 successfully saved
# The 785, label: 8 successfully saved
# The 786, label: 6 successfully saved
# The 787, label: 7 successfully saved
# The 788, label: 0 successfully saved
# The 789, label: 9 successfully saved
# The 790, label: 3 successfully saved
# The 791, label: 0 successfully saved
# The 792, label: 8 successfully saved
# The 793, label: 8 successfully saved
# The 794, label: 9 successfully saved
# The 795, label: 6 successfully saved
# The 796, label: 7 successfully saved
# The 797, label: 8 successfully saved
# The 798, label: 4 successfully saved
# The 799, label: 7 successfully saved
# The 800, label: 5 successfully saved
# The 801, label: 9 successfully saved
# The 802, label: 2 successfully saved
# The 803, label: 6 successfully saved
# The 804, label: 7 successfully saved
# The 805, label: 4 successfully saved
# The 806, label: 5 successfully saved
# The 807, label: 9 successfully saved
# The 808, label: 2 successfully saved
# The 809, label: 3 successfully saved
# The 810, label: 1 successfully saved
# The 811, label: 6 successfully saved
# The 812, label: 3 successfully saved
# The 813, label: 9 successfully saved
# The 814, label: 2 successfully saved
# The 815, label: 2 successfully saved
# The 816, label: 5 successfully saved
# The 817, label: 6 successfully saved
# The 818, label: 8 successfully saved
# The 819, label: 0 successfully saved
# The 820, label: 7 successfully saved
# The 821, label: 7 successfully saved
# The 822, label: 1 successfully saved
# The 823, label: 9 successfully saved
# The 824, label: 8 successfully saved
# The 825, label: 7 successfully saved
# The 826, label: 0 successfully saved
# The 827, label: 9 successfully saved
# The 828, label: 9 successfully saved
# The 829, label: 4 successfully saved
# The 830, label: 6 successfully saved
# The 831, label: 2 successfully saved
# The 832, label: 8 successfully saved
# The 833, label: 5 successfully saved
# The 834, label: 1 successfully saved
# The 835, label: 4 successfully saved
# The 836, label: 1 successfully saved
# The 837, label: 5 successfully saved
# The 838, label: 5 successfully saved
# The 839, label: 1 successfully saved
# The 840, label: 7 successfully saved
# The 841, label: 3 successfully saved
# The 842, label: 6 successfully saved
# The 843, label: 4 successfully saved
# The 844, label: 3 successfully saved
# The 845, label: 2 successfully saved
# The 846, label: 5 successfully saved
# The 847, label: 6 successfully saved
# The 848, label: 4 successfully saved
# The 849, label: 4 successfully saved
# The 850, label: 0 successfully saved
# The 851, label: 4 successfully saved
# The 852, label: 4 successfully saved
# The 853, label: 6 successfully saved
# The 854, label: 7 successfully saved
# The 855, label: 2 successfully saved
# The 856, label: 4 successfully saved
# The 857, label: 3 successfully saved
# The 858, label: 3 successfully saved
# The 859, label: 8 successfully saved
# The 860, label: 0 successfully saved
# The 861, label: 0 successfully saved
# The 862, label: 3 successfully saved
# The 863, label: 2 successfully saved
# The 864, label: 2 successfully saved
# The 865, label: 9 successfully saved
# The 866, label: 8 successfully saved
# The 867, label: 2 successfully saved
# The 868, label: 3 successfully saved
# The 869, label: 7 successfully saved
# The 870, label: 0 successfully saved
# The 871, label: 1 successfully saved
# The 872, label: 1 successfully saved
# The 873, label: 0 successfully saved
# The 874, label: 2 successfully saved
# The 875, label: 3 successfully saved
# The 876, label: 3 successfully saved
# The 877, label: 8 successfully saved
# The 878, label: 4 successfully saved
# The 879, label: 3 successfully saved
# The 880, label: 5 successfully saved
# The 881, label: 7 successfully saved
# The 882, label: 6 successfully saved
# The 883, label: 4 successfully saved
# The 884, label: 7 successfully saved
# The 885, label: 7 successfully saved
# The 886, label: 8 successfully saved
# The 887, label: 5 successfully saved
# The 888, label: 9 successfully saved
# The 889, label: 7 successfully saved
# The 890, label: 0 successfully saved
# The 891, label: 3 successfully saved
# The 892, label: 1 successfully saved
# The 893, label: 6 successfully saved
# The 894, label: 2 successfully saved
# The 895, label: 4 successfully saved
# The 896, label: 3 successfully saved
# The 897, label: 4 successfully saved
# The 898, label: 4 successfully saved
# The 899, label: 7 successfully saved
# The 900, label: 5 successfully saved
# The 901, label: 9 successfully saved
# The 902, label: 6 successfully saved
# The 903, label: 9 successfully saved
# The 904, label: 0 successfully saved
# The 905, label: 7 successfully saved
# The 906, label: 1 successfully saved
# The 907, label: 4 successfully saved
# The 908, label: 2 successfully saved
# The 909, label: 7 successfully saved
# The 910, label: 3 successfully saved
# The 911, label: 6 successfully saved
# The 912, label: 7 successfully saved
# The 913, label: 5 successfully saved
# The 914, label: 8 successfully saved
# The 915, label: 4 successfully saved
# The 916, label: 5 successfully saved
# The 917, label: 5 successfully saved
# The 918, label: 2 successfully saved
# The 919, label: 7 successfully saved
# The 920, label: 1 successfully saved
# The 921, label: 1 successfully saved
# The 922, label: 5 successfully saved
# The 923, label: 6 successfully saved
# The 924, label: 8 successfully saved
# The 925, label: 5 successfully saved
# The 926, label: 8 successfully saved
# The 927, label: 4 successfully saved
# The 928, label: 0 successfully saved
# The 929, label: 7 successfully saved
# The 930, label: 9 successfully saved
# The 931, label: 9 successfully saved
# The 932, label: 2 successfully saved
# The 933, label: 9 successfully saved
# The 934, label: 7 successfully saved
# The 935, label: 7 successfully saved
# The 936, label: 8 successfully saved
# The 937, label: 7 successfully saved
# The 938, label: 4 successfully saved
# The 939, label: 2 successfully saved
# The 940, label: 6 successfully saved
# The 941, label: 9 successfully saved
# The 942, label: 1 successfully saved
# The 943, label: 7 successfully saved
# The 944, label: 0 successfully saved
# The 945, label: 6 successfully saved
# The 946, label: 4 successfully saved
# The 947, label: 2 successfully saved
# The 948, label: 5 successfully saved
# The 949, label: 7 successfully saved
# The 950, label: 0 successfully saved
# The 951, label: 7 successfully saved
# The 952, label: 1 successfully saved
# The 953, label: 0 successfully saved
# The 954, label: 3 successfully saved
# The 955, label: 7 successfully saved
# The 956, label: 6 successfully saved
# The 957, label: 5 successfully saved
# The 958, label: 0 successfully saved
# The 959, label: 6 successfully saved
# The 960, label: 1 successfully saved
# The 961, label: 5 successfully saved
# The 962, label: 1 successfully saved
# The 963, label: 7 successfully saved
# The 964, label: 8 successfully saved
# The 965, label: 5 successfully saved
# The 966, label: 0 successfully saved
# The 967, label: 3 successfully saved
# The 968, label: 4 successfully saved
# The 969, label: 7 successfully saved
# The 970, label: 7 successfully saved
# The 971, label: 5 successfully saved
# The 972, label: 7 successfully saved
# The 973, label: 8 successfully saved
# The 974, label: 6 successfully saved
# The 975, label: 9 successfully saved
# The 976, label: 3 successfully saved
# The 977, label: 8 successfully saved
# The 978, label: 6 successfully saved
# The 979, label: 1 successfully saved
# The 980, label: 0 successfully saved
# The 981, label: 9 successfully saved
# The 982, label: 7 successfully saved
# The 983, label: 1 successfully saved
# The 984, label: 3 successfully saved
# The 985, label: 0 successfully saved
# The 986, label: 5 successfully saved
# The 987, label: 6 successfully saved
# The 988, label: 4 successfully saved
# The 989, label: 4 successfully saved
# The 990, label: 2 successfully saved
# The 991, label: 4 successfully saved
# The 992, label: 4 successfully saved
# The 993, label: 3 successfully saved
# The 994, label: 1 successfully saved
# The 995, label: 7 successfully saved
# The 996, label: 7 successfully saved
# The 997, label: 6 successfully saved
# The 998, label: 0 successfully saved
# The 999, label: 3 successfully saved
# The 1000, label: 6 successfully saved

# %%
convert_to_npy('test', out_dir)
# Out:
# The 60001, label: 7 successfully saved
# The 60002, label: 2 successfully saved
# The 60003, label: 1 successfully saved
# The 60004, label: 0 successfully saved
# The 60005, label: 4 successfully saved
# The 60006, label: 1 successfully saved
# The 60007, label: 4 successfully saved
# The 60008, label: 9 successfully saved
# The 60009, label: 5 successfully saved
# The 60010, label: 9 successfully saved
# The 60011, label: 0 successfully saved
# The 60012, label: 6 successfully saved
# The 60013, label: 9 successfully saved
# The 60014, label: 0 successfully saved
# The 60015, label: 1 successfully saved
# The 60016, label: 5 successfully saved
# The 60017, label: 9 successfully saved
# The 60018, label: 7 successfully saved
# The 60019, label: 3 successfully saved
# The 60020, label: 4 successfully saved
# The 60021, label: 9 successfully saved
# The 60022, label: 6 successfully saved
# The 60023, label: 6 successfully saved
# The 60024, label: 5 successfully saved
# The 60025, label: 4 successfully saved
# The 60026, label: 0 successfully saved
# The 60027, label: 7 successfully saved
# The 60028, label: 4 successfully saved
# The 60029, label: 0 successfully saved
# The 60030, label: 1 successfully saved
# The 60031, label: 3 successfully saved
# The 60032, label: 1 successfully saved
# The 60033, label: 3 successfully saved
# The 60034, label: 4 successfully saved
# The 60035, label: 7 successfully saved
# The 60036, label: 2 successfully saved
# The 60037, label: 7 successfully saved
# The 60038, label: 1 successfully saved
# The 60039, label: 2 successfully saved
# The 60040, label: 1 successfully saved
# The 60041, label: 1 successfully saved
# The 60042, label: 7 successfully saved
# The 60043, label: 4 successfully saved
# The 60044, label: 2 successfully saved
# The 60045, label: 3 successfully saved
# The 60046, label: 5 successfully saved
# The 60047, label: 1 successfully saved
# The 60048, label: 2 successfully saved
# The 60049, label: 4 successfully saved
# The 60050, label: 4 successfully saved
# The 60051, label: 6 successfully saved
# The 60052, label: 3 successfully saved
# The 60053, label: 5 successfully saved
# The 60054, label: 5 successfully saved
# The 60055, label: 6 successfully saved
# The 60056, label: 0 successfully saved
# The 60057, label: 4 successfully saved
# The 60058, label: 1 successfully saved
# The 60059, label: 9 successfully saved
# The 60060, label: 5 successfully saved
# The 60061, label: 7 successfully saved
# The 60062, label: 8 successfully saved
# The 60063, label: 9 successfully saved
# The 60064, label: 3 successfully saved
# The 60065, label: 7 successfully saved
# The 60066, label: 4 successfully saved
# The 60067, label: 6 successfully saved
# The 60068, label: 4 successfully saved
# The 60069, label: 3 successfully saved
# The 60070, label: 0 successfully saved
# The 60071, label: 7 successfully saved
# The 60072, label: 0 successfully saved
# The 60073, label: 2 successfully saved
# The 60074, label: 9 successfully saved
# The 60075, label: 1 successfully saved
# The 60076, label: 7 successfully saved
# The 60077, label: 3 successfully saved
# The 60078, label: 2 successfully saved
# The 60079, label: 9 successfully saved
# The 60080, label: 7 successfully saved
# The 60081, label: 7 successfully saved
# The 60082, label: 6 successfully saved
# The 60083, label: 2 successfully saved
# The 60084, label: 7 successfully saved
# The 60085, label: 8 successfully saved
# The 60086, label: 4 successfully saved
# The 60087, label: 7 successfully saved
# The 60088, label: 3 successfully saved
# The 60089, label: 6 successfully saved
# The 60090, label: 1 successfully saved
# The 60091, label: 3 successfully saved
# The 60092, label: 6 successfully saved
# The 60093, label: 9 successfully saved
# The 60094, label: 3 successfully saved
# The 60095, label: 1 successfully saved
# The 60096, label: 4 successfully saved
# The 60097, label: 1 successfully saved
# The 60098, label: 7 successfully saved
# The 60099, label: 6 successfully saved
# The 60100, label: 9 successfully saved
